# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 2*x**2 - 5*x + 3

# %%
xs = np.arange(-10, 10, 0.5)
ys = f(xs)
ys
# Out:
# array([253., 231., 210., 190., 171., 153., 136., 120., 105.,  91.,  78.,
#         66.,  55.,  45.,  36.,  28.,  21.,  15.,  10.,   6.,   3.,   1.,
#          0.,   0.,   1.,   3.,   6.,  10.,  15.,  21.,  28.,  36.,  45.,
#         55.,  66.,  78.,  91., 105., 120., 136.])

# %%
plt.plot(xs, ys)

# %%
print()
